# %%
from src.classes import Database  

with Database("block_deamon") as db:
    db.execute(f'''
                    CREATE TABLE IF NOT EXISTS example (
                        vault VARCHAR(42) NOT NULL,
                        parent_public_key VARCHAR(98),
                        public_key VARCHAR(98) UNIQUE NOT NULL,
                        private_key VARCHAR(66) UNIQUE NOT NULL,
                        nonce VARCHAR(34) UNIQUE NOT NULL
                    )
                ''')

# %%
from src.classes import Loggable

momo = Loggable(name="momo")
momo.logger.critical('critical message')
# Out:
# [13:11:39] CRITICAL :: critical message
